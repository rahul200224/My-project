# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('/Users/rahulchauhan/Desktop/rahul data sci/Trains schedule.csv')
df.head()
# Out:
#    Unnamed: 0 arrival  day                     train_name  \
# 0           0     NaN  1.0     Falaknuma Lingampalli MMTS
# 1           1     NaN  1.0   Thrissur Guruvayur Passenger
# 2           2     NaN  1.0  Porbandar Muzaffarpur Express
# 3           3     NaN  1.0             RAIPUR ITWARI PASS
# 4           4     NaN  1.0             Gomoh-Asansol MEMU
#
#           station_name station_code      id train_number departure
# 0  KACHEGUDA FALAKNUMA           FM  302214        47154  07:55:00
# 1              THRISUR          TCR  281458        56044  18:55:00
# 2            PORBANDAR          PBR  309335        19269  15:05:00
# 3            RAIPUR JN            R  283774        58205  13:30:00
# 4             GOMOH JN          GMO  319937        63542  07:20:00

# %%
df2 = pd.read_csv('/Users/rahulchauhan/Desktop/rahul data sci/Titanic-Dataset.csv.xls')
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df3 = pd.read_csv('/Users/rahulchauhan/Desktop/rahul data sci/flights.csv')
df3.head()
# Out:
#    id  year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0   0  2013      1    1     517.0             515        2.0     830.0
# 1   1  2013      1    1     533.0             529        4.0     850.0
# 2   2  2013      1    1     542.0             540        2.0     923.0
# 3   3  2013      1    1     544.0             545       -1.0    1004.0
# 4   4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay  ... flight  tailnum origin dest air_time  \
# 0             819       11.0  ...   1545   N14228    EWR  IAH    227.0
# 1             830       20.0  ...   1714   N24211    LGA  IAH    227.0
# 2             850       33.0  ...   1141   N619AA    JFK  MIA    160.0
# 3            1022      -18.0  ...    725   N804JB    JFK  BQN    183.0
# 4             837      -25.0  ...    461   N668DN    LGA  ATL    116.0
#
#    distance  hour  minute            time_hour                    name
# ...

# %%
df4 = pd.read_csv('/Users/rahulchauhan/Desktop/rahul data sci/Iris.csv')
df4.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df5 = pd.read_csv('/Users/rahulchauhan/Desktop/rahul data sci/placement.csv')
df5.head()
#df5.info()
df5
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
# Example: Bar plot of Pclass vs Age from df2
sns.boxplot(x='Pclass', y='Age', hue='Sex', data=df2)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.displot(df2['Age'], kde=True, bins=30)
